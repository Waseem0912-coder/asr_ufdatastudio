# %%
import torch
import torchaudio
import pandas as pd
import IPython
import matplotlib.pyplot as plt
import torchaudio.functional as F
import os

data = df = pd.read_csv("/blue/ufdatastudios/ahmed.waseem/ctc/meta_speaker.csv")
data = data[data['duration'].apply(lambda x: x >= 5)]
audio_folder = "/blue/ufdatastudios/ahmed.waseem/processed_audio"
data["audio_filepath"] = data["audio_filepath"].apply(lambda x: os.path.join(audio_folder, x))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

bundle = torchaudio.pipelines.MMS_FA
model = bundle.get_model(with_star=False).to(device)
LABELS = bundle.get_labels(star=None)

dictionary_path = "/home/ahmed.waseem/Documents/MFA/pretrained_models/dictionary/english_india_mfa.dict"
DICTIONARY = {}
with open(dictionary_path, "r") as f:
    for line in f:
        word, *phonemes = line.strip().split()
        if word not in DICTIONARY:
            DICTIONARY[word] = len(DICTIONARY)

DICTIONARY["*"] = len(DICTIONARY)

def adjust_emission(emission, dictionary_size):
    if emission.size(-1) < dictionary_size:
        pad_size = dictionary_size - emission.size(-1)
        padding = torch.zeros((emission.size(0), emission.size(1), pad_size), device=emission.device)
        emission = torch.cat((emission, padding), dim=-1)
    return emission

def align(emission, tokens):
    targets = torch.tensor([tokens], dtype=torch.int32, device=device)
    alignments, scores = F.forced_align(emission, targets, blank=0)
    alignments, scores = alignments[0], scores[0]
    scores = scores.exp()
    return alignments, scores

def compute_alignments(emission, transcript, dictionary):
    tokens = [dictionary[char] for word in transcript for char in word if char in dictionary]
    alignment, scores = align(emission, tokens)
    token_spans = F.merge_tokens(alignment, scores)
    if len(token_spans) != sum(len(word) for word in transcript if all(char in dictionary for char in word)):
        raise ValueError("Mismatch between token spans and transcript length. Please check the dictionary and transcript.")
    word_spans = unflatten(token_spans, [len(word) for word in transcript if all(char in dictionary for char in word)])
    return word_spans

def unflatten(list_, lengths):
    assert len(list_) == sum(lengths), f"Mismatch: len(list_)={len(list_)} and sum(lengths)={sum(lengths)}"
    i = 0
    ret = []
    for l in lengths:
        ret.append(list_[i : i + l])
        i += l
    return ret

def _score(spans):
    return sum(span.score for span in spans) / len(spans)

def plot_alignments(waveform, token_spans, emission, transcript, sample_rate=bundle.sample_rate):
    ratio = waveform.size(1) / emission.size(1) / sample_rate

    fig, axes = plt.subplots(2, 1)
    axes[0].imshow(emission[0].detach().cpu().T, aspect="auto")
    axes[0].set_title("Emission")
    axes[0].set_xticks([])

    axes[1].specgram(waveform[0], Fs=sample_rate)
    for t_spans, chars in zip(token_spans, transcript):
        t0, t1 = t_spans[0].start + 0.1, t_spans[-1].end - 0.1
        axes[0].axvspan(t0 - 0.5, t1 - 0.5, facecolor="None", hatch="/", edgecolor="white")
        axes[1].axvspan(ratio * t0, ratio * t1, facecolor="None", hatch="/", edgecolor="white")
        axes[1].annotate(f"{_score(t_spans):.2f}", (ratio * t0, sample_rate * 0.51), annotation_clip=False)

        for span, char in zip(t_spans, chars):
            t0 = span.start * ratio
            axes[1].annotate(char, (t0, sample_rate * 0.55), annotation_clip=False)

    axes[1].set_xlabel("time [second]")
    axes[1].set_xlim([0, None])
    fig.tight_layout()

for idx, row in df.iterrows():
    audio_filepath = row['audio_filepath']
    transcript = row['text'].split()

    waveform, sample_rate = torchaudio.load(audio_filepath)

    with torch.inference_mode():
        emission, _ = model(waveform.to(device))
    star_dim = torch.zeros((1, emission.size(1), 1), device=emission.device, dtype=emission.dtype)
    emission = torch.cat((emission, star_dim), 2)

    emission = adjust_emission(emission, len(DICTIONARY))

    try:
        word_spans = compute_alignments(emission, transcript, DICTIONARY)
        plot_alignments(waveform, word_spans, emission, transcript)
        plt.show()
    except ValueError as e:
        print(f"Error processing row {idx}: {e}")
# Out:
# /scratch/local/48887333/ipykernel_97673/504395793.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["audio_filepath"] = data["audio_filepath"].apply(lambda x: os.path.join(audio_folder, x))
# cuda
# Error processing row 0: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 1: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 2: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 3: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 4: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 5: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 6: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 7: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 8: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 9: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 10: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 11: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 12: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 13: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 14: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 15: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 16: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 17: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 18: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 19: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 22: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 23: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 24: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 25: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 26: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 27: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 28: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 29: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 30: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 31: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 32: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 33: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 34: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 35: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 36: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 37: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 38: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 39: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 40: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 41: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 42: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 43: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 44: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 45: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 46: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 47: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 48: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 49: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 50: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 51: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 52: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 53: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 54: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 55: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 56: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 57: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 58: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 59: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 60: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 61: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 62: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 63: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 64: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 65: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 66: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 67: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 68: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 69: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 70: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 71: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 72: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 73: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 74: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 75: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 76: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 77: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 78: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 79: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 80: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 81: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 82: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 83: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 84: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 85: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 86: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 87: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 88: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 89: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 90: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 91: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 92: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 93: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 94: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 95: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 96: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 97: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 98: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 99: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 100: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 101: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 102: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 103: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 104: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 105: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 106: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 107: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 108: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 109: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 110: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 111: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 112: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 113: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 114: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 115: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 116: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 117: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 118: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 119: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 120: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 121: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 122: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 123: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 124: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 125: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 126: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 127: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 129: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 130: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 132: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 133: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 134: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 135: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 136: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 137: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 138: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 139: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 140: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 141: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 142: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 143: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 144: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 145: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 146: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 147: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 148: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 149: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 150: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 151: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 152: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 153: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 154: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 156: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 157: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 158: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 159: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 160: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 161: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 162: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 163: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 165: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 166: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 167: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 168: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 169: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 170: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 171: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 172: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 173: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 174: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 175: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 176: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 177: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 178: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 179: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 180: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 181: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 182: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 183: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 184: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 185: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 186: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 187: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 188: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 189: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 190: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 191: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 193: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 194: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 195: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 196: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 197: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 198: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 199: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 200: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 201: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 202: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 203: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 204: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 205: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 207: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 208: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 209: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 210: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 211: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 212: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 213: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 214: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 215: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 216: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 217: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 218: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 219: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 220: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 221: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 222: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 223: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 224: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 225: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 226: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 227: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 228: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 229: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 230: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 231: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 232: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 233: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 235: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 237: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 238: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 239: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 240: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 241: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 242: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 243: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 244: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 245: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 246: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 247: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 248: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 249: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 250: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 252: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 253: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 254: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 255: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 256: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 257: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 258: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 259: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 260: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 261: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 262: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 263: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 264: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 265: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 266: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 267: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 268: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 269: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 270: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 271: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 272: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 273: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 274: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 275: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 276: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 277: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 278: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 279: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 280: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 281: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 282: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 283: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 284: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 285: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 286: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 287: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 288: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 289: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 290: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 291: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 292: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 293: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 294: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 295: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 296: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 297: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 298: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 299: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 300: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 301: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 302: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 303: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 304: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 305: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 306: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 307: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 308: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 309: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 310: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 311: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 312: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 313: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 315: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 316: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 317: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 318: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 319: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 320: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 321: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 322: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 323: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 324: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 325: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 326: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 327: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 328: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 329: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 330: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 331: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 332: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 333: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 334: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 335: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 336: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 337: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 338: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 339: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 340: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 341: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 342: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 343: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 344: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 345: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 346: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 347: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 348: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 349: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 350: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 351: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 352: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 353: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 354: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 355: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 356: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 357: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 358: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 360: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 361: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 362: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 363: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 364: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 365: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 366: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 367: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 368: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 369: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# Error processing row 370: Mismatch between token spans and transcript length. Please check the dictionary and transcript.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 113
#     111 # Compute word spans and plot the alignment
#     112 try:
# --> 113     word_spans = compute_alignments(emission, transcript, DICTIONARY)
#     114     plot_alignments(waveform, word_spans, emission, transcript)
#     115     plt.show()  # Display the plot for each row
#
# Cell In[9], line 52, in compute_alignments(emission, transcript, dictionary)
#      50 def compute_alignments(emission, transcript, dictionary):
#      51     tokens = [dictionary[char] for word in transcript for char in word if char in dictionary]
# ---> 52     alignment, scores = align(emission, tokens)
#      53     token_spans = F.merge_tokens(alignment, scores)
#      54     if len(token_spans) != sum(len(word) for word in transcript if all(char in dictionary for char in word)):
#
# Cell In[9], line 45, in align(emission, tokens)
#      43 def align(emission, tokens):
#      44     targets = torch.tensor([tokens], dtype=torch.int32, device=device)
# ---> 45     alignments, scores = F.forced_align(emission, targets, blank=0)
#      46     alignments, scores = alignments[0], scores[0]  # remove batch dimension for simplicity
#      47     scores = scores.exp()  # convert back to probability
#
# File /blue/arthur.porto-biocosmos/ahmed.waseem/.conda/envs/ctc_seg/lib/python3.10/site-packages/torchaudio/functional/_alignment.py:58, in forced_align(log_probs, targets, input_lengths, target_lengths, blank)
#      56 if blank in targets:
#      57     raise ValueError(f"targets Tensor shouldn't contain blank index. Found {targets}.")
# ---> 58 if torch.max(targets) >= log_probs.shape[-1]:
#      59     raise ValueError("targets values must be less than the CTC dimension")
#      61 if input_lengths is None:
#
# RuntimeError: max(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
